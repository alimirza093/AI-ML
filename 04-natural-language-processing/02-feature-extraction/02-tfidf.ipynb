# %%
from sklearn.feature_extraction.text import TfidfVectorizer

document = [
    'I Love Pizza',
    'Pizza Is Great',
    'I Love Pasta',
    'Pasta Was Good',
    'Pizza And Pasta Was Tasty'
]

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(document)

print('Vocabulary: ',vectorizer.get_feature_names_out())
print('Bow Matrix:\n',X.toarray())
# Out:
# Vocabulary:  ['and' 'good' 'great' 'is' 'love' 'pasta' 'pizza' 'tasty' 'was']
# Bow Matrix:
#  [[0.         0.         0.         0.         0.76944707 0.
#   0.63871058 0.         0.        ]
#  [0.         0.         0.63907044 0.63907044 0.         0.
#   0.42799292 0.         0.        ]
#  [0.         0.         0.         0.         0.76944707 0.63871058
#   0.         0.         0.        ]
#  [0.         0.69015927 0.         0.         0.         0.4622077
#   0.         0.         0.55681615]
#  [0.53089869 0.         0.         0.         0.         0.35554904
#   0.35554904 0.53089869 0.42832572]]
