# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/Titanic-Dataset.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df = df.drop(['Name'],axis=1)

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='str')

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df.dropna(subset=['Embarked'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  889 non-null    int64
#  1   Pclass    889 non-null    int64
#  2   Name      889 non-null    str
#  3   Sex       889 non-null    str
#  4   Age       889 non-null    float64
#  5   SibSp     889 non-null    int64
#  6   Parch     889 non-null    int64
#  7   Fare      889 non-null    float64
#  8   Embarked  889 non-null    str
# dtypes: float64(2), int64(4), str(3)
# memory usage: 69.5 KB

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
from sklearn.preprocessing import LabelEncoder

columns = ['Sex','Embarked']
encoded = df.copy()
for i in columns:
    le = LabelEncoder()
    encoded[columns] = le.fit_transform(encoded[columns])

encoded
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 7
#       3 columns = ['Sex','Embarked']
#       4 encoded = df.copy()
#       5 for i in columns:
#       6     le = LabelEncoder()
# ----> 7     encoded[columns] = le.fit_transform(encoded[columns])
#       8
#       9 encoded
#
# File ~/AI-ML-DS/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:120, in LabelEncoder.fit_transform(self, y)
#     107 def fit_transform(self, y):
#     108     """Fit label encoder and return encoded labels.
#     109
#     110     Parameters
#    (...)    118         Encoded labels.
#     119     """
# --> 120     y = column_or_1d(y, warn=True)
#     121     self.classes_, y = _unique(y, return_inverse=True)
#     122     return y
#
# File ~/AI-ML-DS/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:1434, in column_or_1d(y, dtype, input_name, warn, device)
#    1421         warnings.warn(
#    1422             (
#    1423                 "A column-vector y was passed when a 1d array was"
#    (...)   1428             stacklevel=2,
#    1429         )
#    1430     return _asarray_with_order(
#    1431         xp.reshape(y, (-1,)), order="C", xp=xp, device=device
#    1432     )
# -> 1434 raise ValueError(
#    1435     "y should be a 1d array, got an array of shape {} instead.".format(shape)
#    1436 )
#
# ValueError: y should be a 1d array, got an array of shape (889, 2) instead.
